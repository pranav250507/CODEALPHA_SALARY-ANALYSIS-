# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("data_jobs_salary_monthly.xlsx")

# %%
df.head()
# Out:
#   job_title_short                                          job_title  \
# 0  Data Scientist                        Data Scientist - TikTok Ads
# 1  Data Scientist                Data Scientist - Technical Platform
# 2  Data Scientist                   Data Scientist - Computer Vision
# 3  Data Scientist  Senior Actuarial Consultant and Data Scientist...
# 4  Data Scientist  Data Scientist Digital Effectiveness Operation...
#
#         job_location                    job_via job_schedule_type  \
# 0  Mountain View, CA               via LinkedIn         Full-time
# 1  Mountain View, CA               via LinkedIn         Full-time
# 2      Paris, France            via Ai-Jobs.net         Full-time
# 3      Las Vegas, NV  via Las Vegas, NV - Geebo         Full-time
# 4       Sun City, AZ           via ZipRecruiter         Full-time
#
#    job_work_from_home            search_location     job_posted_date  \
# 0               False  California, United States 2023-01-02 15:01:03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3102 entries, 0 to 3101
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        3102 non-null   object
#  1   job_title              3102 non-null   object
#  2   job_location           3080 non-null   object
#  3   job_via                3102 non-null   object
#  4   job_schedule_type      3090 non-null   object
#  5   job_work_from_home     3102 non-null   bool
#  6   search_location        3102 non-null   object
#  7   job_posted_date        3102 non-null   datetime64[ns]
#  8   job_no_degree_mention  3102 non-null   bool
#  9   job_health_insurance   3102 non-null   bool
#  10  job_country            3102 non-null   object
#  11  salary_rate            3102 non-null   object
#  12  salary_year_avg        2287 non-null   float64
#  13  salary_hour_avg        815 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# job_title_short             0
# job_title                   0
# job_location               22
# job_via                     0
# job_schedule_type          12
# job_work_from_home          0
# search_location             0
# job_posted_date             0
# job_no_degree_mention       0
# job_health_insurance        0
# job_country                 0
# salary_rate                 0
# salary_year_avg           815
# salary_hour_avg          2287
# company_name                0
# job_skills                281
# dtype: int64

# %%
df.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# job_title_short             0
# job_title                   0
# job_location               22
# job_via                     0
# job_schedule_type          12
# job_work_from_home          0
# search_location             0
# job_posted_date             0
# job_no_degree_mention       0
# job_health_insurance        0
# job_country                 0
# salary_rate                 0
# salary_year_avg           815
# salary_hour_avg          2287
# company_name                0
# job_skills                281
# dtype: int64

# %%
df = df.dropna(subset=['salary_year_avg'])

# %%
df
# Out:
#      job_title_short                                          job_title  \
# 0     Data Scientist                        Data Scientist - TikTok Ads
# 1     Data Scientist                Data Scientist - Technical Platform
# 2     Data Scientist                   Data Scientist - Computer Vision
# 4     Data Scientist  Data Scientist Digital Effectiveness Operation...
# 5     Data Scientist               Data Scientist - Marketing Analytics
# ...              ...                                                ...
# 3094    Data Analyst  Data Analyst - Strategy, Transformation & Capa...
# 3095    Data Analyst                                 BI Data Analyst IV
# 3098    Data Analyst          Data Analyst, Talent Acquisition - REMOTE
# 3099   Data Engineer                   Staff Data Engineer - Full Stack
# 3100    Data Analyst                       Material Data Analyst II SKA
#
#                      job_location           job_via job_schedule_type  \
# ...

# %%
df = df.dropna(subset=['job_country'])

# %%
df = df.dropna(subset=['company_name'])

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# job_title_short                  object
# job_title                        object
# job_location                     object
# job_via                          object
# job_schedule_type                object
# job_work_from_home                 bool
# search_location                  object
# job_posted_date          datetime64[ns]
# job_no_degree_mention              bool
# job_health_insurance               bool
# job_country                      object
# salary_rate                      object
# salary_year_avg                 float64
# salary_hour_avg                 float64
# company_name                     object
# job_skills                       object
# dtype: object

# %%
df['Year'] = df['job_posted_date'].dt.year

# %%
df['salary_year_avg'].describe()
# Out:
# count      2287.000000
# mean     123064.162150
# std       47367.702396
# min       32500.000000
# 25%       90000.000000
# 50%      115000.000000
# 75%      150000.000000
# max      475000.000000
# Name: salary_year_avg, dtype: float64

# %%
len(df)
# Out:
# 2287

# %%
df['company_name'].nunique()
# Out:
# 1262

# %%
df['job_country'].nunique()
# Out:
# 65

# %%
df['salary_year_avg'].mean()
# Out:
# np.float64(123064.16214951355)

# %%
df['salary_year_avg'].max()
# Out:
# 475000.0

# %%
df.to_excel("cleaned_jobs_salary.xlsx", index=False)

# %%
import pandas as pd

df = pd.read_excel("cleaned_jobs_salary.xlsx")
df.head()
# Out:
#   job_title_short                                          job_title  \
# 0  Data Scientist                        Data Scientist - TikTok Ads
# 1  Data Scientist                Data Scientist - Technical Platform
# 2  Data Scientist                   Data Scientist - Computer Vision
# 3  Data Scientist  Data Scientist Digital Effectiveness Operation...
# 4  Data Scientist               Data Scientist - Marketing Analytics
#
#         job_location           job_via job_schedule_type  job_work_from_home  \
# 0  Mountain View, CA      via LinkedIn         Full-time               False
# 1  Mountain View, CA      via LinkedIn         Full-time               False
# 2      Paris, France   via Ai-Jobs.net         Full-time               False
# 3       Sun City, AZ  via ZipRecruiter         Full-time               False
# 4         Irving, TX      via LinkedIn         Full-time               False
#
#              search_location     job_posted_date  job_no_degree_mention  \
# ...

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Pranav

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.antigravity',
#  '.bash_history',
#  '.conda',
#  '.continuum',
#  '.copilot',
#  '.dbus-keyrings',
#  '.dia',
#  '.gemini',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jdks',
#  '.junie',
#  '.jupyter',
#  '.lemminx',
#  '.m2',
#  '.matplotlib',
#  '.ms-ad',
#  '.node_repl_history',
#  '.th-client',
#  '.virtual_documents',
#  '.vscode',
#  '.vscode-shared',
#  'anaconda3',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'cleaned_jobs_salary.xlsx',
#  'Contacts',
#  'Cookies',
#  'data_jobs_salary_monthly.xlsx',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'hi.c',
#  'hi.exe',
#  'IdeaProjects',
#  'Links',
#  'Local Settings',
#  'logs',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TM.blf',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000001.regtrans-ms',
# ...

# %%
df.to_excel("cleaned_jobs_salary.xlsx", index=False)

# %%
print(os.getcwd())
# Out:
# C:\Users\Pranav
